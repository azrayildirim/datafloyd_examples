# %% [markdown]
# <h1>İçindekiler<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ConvNet-nedir?" data-toc-modified-id="ConvNet-nedir?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>ConvNet nedir?</a></span></li><li><span><a href="#Katmanlar" data-toc-modified-id="Katmanlar-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Katmanlar</a></span><ul class="toc-item"><li><span><a href="#Convolutional-Layer" data-toc-modified-id="Convolutional-Layer-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Convolutional Layer</a></span><ul class="toc-item"><li><span><a href="#Python'da-&quot;convolution&quot;-nasıl-yapılır?-Çıkan-sonuçlar-nasıl-yorumlanır?" data-toc-modified-id="Python'da-&quot;convolution&quot;-nasıl-yapılır?-Çıkan-sonuçlar-nasıl-yorumlanır?-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Python'da "convolution" nasıl yapılır? Çıkan sonuçlar nasıl yorumlanır?</a></span></li><li><span><a href="#ConvNet'te-filtreler-neler-öğreniyor?" data-toc-modified-id="ConvNet'te-filtreler-neler-öğreniyor?-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>ConvNet'te filtreler neler öğreniyor?</a></span></li></ul></li><li><span><a href="#Pooling-Layer" data-toc-modified-id="Pooling-Layer-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Pooling Layer</a></span></li><li><span><a href="#Activation-Layer" data-toc-modified-id="Activation-Layer-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Activation Layer</a></span></li><li><span><a href="#Flatten-Layer" data-toc-modified-id="Flatten-Layer-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Flatten Layer</a></span></li><li><span><a href="#Fully-Connected-Layer" data-toc-modified-id="Fully-Connected-Layer-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Fully Connected Layer</a></span></li><li><span><a href="#Normalization-Layer" data-toc-modified-id="Normalization-Layer-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Normalization Layer</a></span></li><li><span><a href="#Dropout-Layer" data-toc-modified-id="Dropout-Layer-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Dropout Layer</a></span></li></ul></li><li><span><a href="#Bir-ConvNet-Örneği---VGGNet" data-toc-modified-id="Bir-ConvNet-Örneği---VGGNet-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Bir ConvNet Örneği - VGGNet</a></span><ul class="toc-item"><li><span><a href="#İlk-katmandaki-filtrelerin-görselleştirilmesi" data-toc-modified-id="İlk-katmandaki-filtrelerin-görselleştirilmesi-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>İlk katmandaki filtrelerin görselleştirilmesi</a></span></li></ul></li></ul></div>

# %% [markdown]
# # ConvNet nedir?

# %% [markdown]
# Tek bir cümleyle özetleyecek olursak, "Convolutional Neural Networks" (ConvNet) en çok kullanılan derin öğrenme mimarisidir.

# %% [markdown]
# ConvNet'ler yeterli ve kaliteli veri ile buluştuğu zaman bir çok problemde **"accuracy" değeri çok yüksek sonuçlar elde edilmesine** olanak sağlamaktadır.

# %% [markdown]
# >Günümüzde özellikle "computer vision" alanı ConvNet'ler ile çağ atlamıştır. Yani ConvNet'ler sayesinde bilgisayarlar insanlara yakın ve hatta insanlardan daha yüksek bir doğrulukla resimleri tanıyabilmekte, resimlerin içindeki nesneleri tespit edebilmekte ve daha birçok operasyonu gerçekleştirebilmektedir.

# %% [markdown]
# ConvNet mimarilerin atası sayılabilecek ilk mimariyi **Yann LeCun**'ın 1989 yılındaki ["Object Recognition with Gradient-Based Learning"](http://yann.lecun.com/exdb/publis/pdf/lecun-99.pdf) makalesinde görüyoruz. Daha sonra bu mimari biraz daha geliştirilerek 1998 yılında LeNet-5 halini almıştır. *Bu yöntemin o yıllarda karakter tanıma ile ilgili ticari ürünlerde de kullanıldığını belirtmekte fayda var.*

# %% [markdown]
# ![lecun.png](lecun.png)
# <p style="text-align: center;"> <i>Yann LeCun (AI Director of Facebook 2019) <i> </p>

# %% [markdown]
# >Her ne kadar hatırı sayılır bir süredir bu metotlar biliniyor olsa da, bunların gerçek anlamda faydalı hale gelmesi GPU teknolojisinin gelişip çok daha derin mimarilerin büyük veriler üzerinde eğitilmesi sonucu olmuştur.

# %% [markdown]
# > ConvNet'ler ilk büyük zaferini 2012 yılında AlexNet mimarisinin, "ImageNet Large Scale Visual Recognition Challenge" yarışmasında rakiplerine fark atarak birinci olmasıyla elde etmişlerdir.

# %% [markdown]
# -----------------

# %% [markdown]
# ![first_conv_net.png](first_conv_net.png)

# %% [markdown]
# Yukarıdaki mimariyi biraz incelediğimizde temelde bir aşağıdaki adımların olduğunu görüyoruz:
# 1. Resim üzerindeki convolution operasyonları
# 2. Subsampling operasyonları
# 3. Full connection ve Gaussian Connection operasyonları

# %% [markdown]
# Bu aşamaların herbirine katman (layer) denilmektedir. Bu mimaride bahsedilenlerin dışında **max pooling**, **batch normalization** gibi birçok katman daha günümüzdeki mimarilerde kullanılmaktadır.

# %% [markdown]
# <div class="alert alert-warning">
# ConvNet katmanlardan oluşmuş bir yapıdır. Her katman 3 boyutlu bir girdiyi yine 3 boyutlu bir çıktıya dönüştürür. <br> Bu yazımızda ConvNet'lerde kullanılan önemli katmanların aslında ne iş yaptığını inceleyeceğiz.
# </div>

# %% [markdown]
# ![conv_net_ex.PNG](conv_net_ex.PNG)
# Ref: http://cs231n.github.io/convolutional-networks/

# %% [markdown]
# # Katmanlar

# %% [markdown]
# ## Convolutional Layer

# %% [markdown]
# "Convolution" lafını her duyduğumda aklıma sayın hocam **Bülent Sankur** gelir. Kendisi sinyal dersinde bize bu kelimenin ne anlama geldiğini anlatmıştı. Daha dün gibi hatılıyorum "Convolution" kelimesinin "Co-Evolution"dan geldiğini  söylemişti, yani **birlikte evrim geçirmek**. Gerçekten de iki sinyalin geçirdiği transformasyonu çok güzel anlatan bir kelime olduğunu düşünmüştüm. Bunun Türkçe çevriminin de doğal olarak **"evrişim"** olduğunu belirtmişti.

# %% [markdown]
# > **Basitleştirilmiş tanım:** "Convolution" büyük bir resmin daha küçük bir resim ile çarpılmasıdır. Bu çarpım büyük resim üzerinde kaydırma yapılarak her adım için gerçekleştirilir.

# %% [markdown]
# <div class="alert alert-info">
#   <strong>**BONUS**</strong><br>
#   Siz sevgili okurlarım için convolution olayını daha iyi anlatabilmek için aşağıdaki video'yu hazırladım. Faydalı olması dileğimle..
# </div>
# <br>

# %% [markdown]
# **Videodaki ana başlıklar**
# * "Convolution" mekanizması nasıl çalışır?
# * Adım adım "convolution" örneği
# * Neden önemlidir?
# * Önemli kavramlar
#     * Filtre boyutu (Filter size)
#     * Sıfır ekleme (Zero Padding)
#     * Kaydırma (Stride)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('33kTsvenLec',width=640,height=480)

# %% [markdown]
# Yukarıdaki video umarım faydalı olmuştur. Bu tip videolardan daha çok hazırlamayı düşünüyorum önümüzdeki günlerde.<br>

# %% [markdown]
# >Peki nedir "convolution"ı özel yapan?

# %% [markdown]
# ### Python'da "convolution" nasıl yapılır? Çıkan sonuçlar nasıl yorumlanır?

# %% [markdown]
# Bir resmi başka bir resim ile "convolve" yaptığımızda aslında bir filtreleme operasyonu gerçekleştiririz. **Yani küçük filtrede bulunan şekiller büyük resimde de ortaya çıktığı yerde sonuç yüksek olur.** Şekillerin tam olarak benzemesine de gerek yoktur. Tam olarak benzerse sonuç çok yüksek biraz benzerse sonuç düşük çıkar. Basit bir örnekle açıklayalım.

# %% [markdown]
# >"Convolution" renkli imgelere de uygulanabilir, fakat basit olması açısından burada siyah-beyaz imgeler (yani 2 boyutlu) üzerinde bir örnek yapalım

# %% [markdown]
# Elimizde paint programı yoluyla hazırlanmış 128x128'lik bir imge olsun. Bu imgenin içinde 3x3 piksel boyutlarında artılar mevcut

# %%
# %matplotlib notebook
# opencv modülünü yüklüyoruz
import cv2
import matplotlib.pyplot as plt
pluses = cv2.imread("pluses.bmp")
# siyah beyaza çevirelim
pluses = cv2.cvtColor(pluses,cv2.COLOR_BGR2GRAY)
plt.figure()
plt.imshow(pluses,cmap="gray")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# >Şimdi bununla "convolve" yapacağımız "kernel" (küçük resim) tek bir artıdan oluşsun. Yani 3x3 boyutlarında bir artıdan söz ediyorum. matplotlib kütüphanesi boyutları büyüttüğü için rahatlıla görebilirsiniz.

# %%
single_plus = cv2.imread("single_plus.bmp")
# siyah beyaza çevirelim
single_plus = cv2.cvtColor(single_plus,cv2.COLOR_BGR2GRAY)
plt.figure()
plt.imshow(single_plus,cmap="gray")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Convolution için scipy kütüphanesini kullanacağı
from scipy.signal import convolve2d
import numpy as np
out = convolve2d(pluses,single_plus,mode="full")
plt.figure()
plt.imshow(out,cmap="gray");
print(np.max(out))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 5

# %%
from scipy.signal import convolve2d
import numpy as np
# big = np.array([
# [2,3,1,1,0],
# [0,1,2,2,1],
# [3,1,2,1,0],
# [0,1,2,3,1],
# [1,3,1,1,2]])
big = np.array([
[2,1,0],
[3,2,0],
[1,1,2]])

small = np.array([[0,1,0],[1,2,1],[0,1,0]])
out = convolve2d(big,small,mode="same")
print(out)
# Out:
# [[ 8  6  1]
#  [11  9  4]
#  [ 6  7  5]]

# %% [markdown]
# >Yukarıdaki resimde artıların olduğu noktalarda yüksek yoğunluklu bir beyazlık olduğunu görüyoruz. Yani bu çıktı ile ilk imgedeki artıların tam merkezlerini bulmak mümkün!

# %%
locations = np.where([out == np.max(out)])
print("y koordinatları")
print(locations[1])
print("x koordinatları")
print(locations[2])
# Out:
# y koordinatları
# [1]
# x koordinatları
# [0]

# %% [markdown]
# ### ConvNet'te filtreler neler öğreniyor?

# %% [markdown]
# <div class="alert alert-warning">
# ConvNet mimarilerinde bu "kernel" veya "filtre" dediğimiz yapılardan (örnekteki küçük artı) bir sürü var. İşin güzel tarafı bu filtrelerin katsayıları yani içerdikleri rakamlar yapay sinir ağının eğitimi sırasında otomatik olarak belirleniyorlar. Yani eğitim için kullandığınız veri setindeki temel yapıları öğreniyorlar!
# </div>

# %% [markdown]
# Örneğin aşağıdaki makalede bir convnet'in öğrendiği filtreleri örneklendirmişler. Buradaki filtrelerin ve genellikle derin öğrenmede kulllanılan filtrelerin üç boyutlu olduğunu belirtmekte fayda var.

# %% [markdown]
# ![ogrenilen_filtreler.png](ogrenilen_filtreler.png)
# [ImageNet Classification with Deep Convolutional Neural Networks](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf)

# %% [markdown]
# ## Pooling Layer

# %% [markdown]
# Ref: http://deeplearning.net/software/theano/tutorial/conv_arithmetic.html

# %% [markdown]
# "Pooling" katmanı "convolution"a çok benzer. Bu operasyonda da yine belirli bir büyüklüğe sahip filtremiz vardır ve bu filtreyi büyük resmin üzerinde dolaştırırız.

# %% [markdown]
# Yapılan işlem ise filtrenin içindeki büyük resme ati tek bir sayıyı seçmektir. Bu sayıyı nasıl seçtiğimiz filtrenin tipini belirler. Örneğin:
# * Eğer en büyük sayı seçiliyorsa "max pooling"
# * Sayıların ortalamaları alınıyorsa "average pooling"
# katmanı kullanılıyor deriz

# %% [markdown]
# ![max_pool.png](max_pool.png)

# %% [markdown]
# ## Activation Layer

# %% [markdown]
# Aktivasyon katmanları genellikle "Flatten" veya "Convolution" katmanlarından sonra kullanılır ve neuronların çıktısını regüle etmek için kullanılır. Bu kısımdaki fonksiyonlar oldukça önemli oldukları için bunlaırn üzerinde biraz daha duracağız.

# %% [markdown]
# Belli başlı kullanılan aktivasyon fonksiyonları

# %% [markdown]
# >ReLU (Rectified Linear Unit)

# %% [markdown]
# En çok kullanılan aktivasyon fonksiyonudur. Ne yapacağınızı bilmiyorsanız bunu kullanın :) Sıfırdan büyük sayılar için lineer davranır, sıfırdan küçük sayılar için 0'dır. Şimdi bunun fonksiyonunu yazalım.

# %%
import numpy as np
import matplotlib.pyplot as plt
def relu(x):
    out = np.zeros(len(x))
    out[x>0] = x[x>0]
    return out

x = np.linspace(-10,10,100)
y = relu(x)


plt.figure()
plt.plot(x,y)
plt.grid()
plt.title("ReLU")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# >Sigmoid

# %% [markdown]
# Bunu belki logistic regression'dan hatırlarsınız. Yaptığı şey girdiyi 0 ile 1 arasına sıkıştırmaktır. Çok büyük değerler yani yaklaşık 5'ten sonra çıktı olarak 1 verir. Aşağıdaki gibi bir fonksiyona sahiptir.

# %% [markdown]
# \begin{equation*}
# f(x)=\frac{1}{1+e^{-x}}
# \end{equation*}

# %%
def sigmoid(x):
    # ilk denklem
    out = 1 / (1 + np.exp(-x))

    return out

x = np.linspace(-10,10,100)
y = sigmoid(x)


plt.figure()
plt.plot(x,y)
plt.grid()
plt.title("Sigmoid")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Bu fonksiyon geçmişte çok kullanılmıştır. Çünkü karakteristiği fiziksel bir nöronun ateşlenmesine çok benzemektedir.

# %% [markdown]
# **Fakat sigmoid fonksiyonu çok tercih edilmez.** Çünkü sinir ağlarının eğitimi sırasında gradyanların kaybolmasına sebep olur, bir başka deyişle yapay sinir ağları kısa bir sürede öğrenemez hale gelir. Kullanılmamasının ikinci bir sebebi de bu fonksiyonun 0 etrafında simetrik olmamasıdır.

# %% [markdown]
# >Tanh

# %% [markdown]
# Sigmoid'in 0 etrafında simetrik hale getirilmesi ile oluşur. Sigmoid'e göre simetrik olması nedeniyle daha iyidir ama bu da çok tercih edilen bir fonksiyon değildir.

# %%
def tanh(x):
    # ilk denklem
    out = 2*sigmoid(2*x) - 1

    return out

x = np.linspace(-10,10,100)
y = tanh(x)


plt.figure()
plt.plot(x,y)
plt.grid()
plt.title("Tanh")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# >Leaky ReLU

# %% [markdown]
# ReLU'nun çok avantajlı olduğunu söylemiştik. Tekrar edecek olursak:
# * Sigmoid ve Tanh'deki exp operasyonlarına karşılık ReLU'da sadece kıyaslama kullanılır bu sebeple çok hızlıdır
# * Sigmoid ve Tanh'ye kıyasla yapay sinir ağının çok hızlı yakınsayıp, kısa sürede yüksek performans değerleri elde etmesini sağlar.

# %% [markdown]
# Ne yazık ki ReLU'nun da bazı dezavantajarı vardır. Bunlardan en başta geleni; nöronun eğitim sırasında ölmesine sebep olmasıdır. Ölen nöron eğitim boyunca bir daha aktive olmaz. Öğrenme hızı yüksek yapıldığında genellikle bu fenomenle karılaşılmaktadır.

# %% [markdown]
# ReLu'nun bu dezavantajını gidermek için negatif değerlerde 0 yerine çok küçük değer alan "Leaky Relu" önerilmektedir.

# %%
def leaky_relu(x,alpha=0.05):
    out = np.zeros(len(x))
    out[x>0] = x[x>0]
    out[x<=0] = x[x<=0]*alpha
    return out

x = np.linspace(-10,10,100)
y = leaky_relu(x)


plt.figure()
plt.plot(x,y)
plt.grid()
plt.title("Leaky ReLU")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Literatürde bu yöntemin başarılı olduğuna dair bir fikir birliği yoktur. [*](http://cs231n.github.io/neural-networks-1/)

# %% [markdown]
# >Maxout

# %% [markdown]
# Ian Goodfellow tarafından önerilmiş bir [yöntemdir](https://arxiv.org/pdf/1302.4389.pdf). Şu fonksiyonu kullanır:
# $$\max(w_1^Tx+b_1, w_2^Tx + b_2)$$
# Bu yöntemde aktivasyon fonksiyonu da $w_1,b_1,w_2,b_2$ parametreleri vasıtası ile öğrenilmektedir. Ne yazık ki bu yöntem katman başına parametrelerin ikiye katlanmasına sebep olmaktadır.

# %% [markdown]
# ## Flatten Layer

# %% [markdown]
# Bu katman kendine gelen girdiyi tek boyutlu hale indirir. Yani diyelim ki (64,64,3) boyutunda bir imgemiz var. Bunu "flatten" yaptığımız zaman 64\*64\*3 =    12288 boyutunda bir vektör elde ederiz.

# %% [markdown]
# Genellikle "Fully Connected" katmandan önce kullanılır.

# %% [markdown]
# ## Fully Connected Layer

# %% [markdown]
# Bir önceki katmana tümüyle bağlanan nöronlardan oluşur. Klasik bir yapay sinir ağını anlatmaktadır.

# %% [markdown]
# ## Normalization Layer

# %% [markdown]
# İstatistiksel normalizasyon en basit haliyle bir veriyi ortalaması 0 ve varyansı 1 haline getirmek olarak tanımlanabilir.

# %% [markdown]
# Derin öğrenme mimarilerinde "batch normalization" genellikle bir katmandan hemen sonra aktivasyon fonksiyonu çağrılmadan önce kullanılır. Buradaki amaç çıktıları normalize ederek regularizasyon sağlamak ve yapay sinir ağının "overfit" yapmasını engellemektir.

# %% [markdown]
# Batch Normalization ile ilgili en önemli makale aşağıdaki bağlantıdadır: <br>
# [Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift](https://arxiv.org/abs/1502.03167)

# %% [markdown]
# ## Dropout Layer

# %% [markdown]
# Bu katman eğitim sırasında her iterasyonda belirli oranda nöronun rastgele kapatılmasını sağlar. Ayrıntısına girmeden bunun da önemli bir regülarizasyon tekniği olduğunu söyleyebiliriz. Aşağıdaki örnekte dropout değeri 0.5 olan katmanın her seferinde farklı nöronlarının aktive olduğunu görebiliriz.

# %% [markdown]
# ![dropout.gif](dropout.gif "segment")
# [Reference](https://www.analyticsvidhya.com/blog/2018/04/fundamentals-deep-learning-regularization-techniques/)

# %% [markdown]
# Bu konuda en önemli makale Dropout Paper olarak da bilinir, daha fazla bilgi için bakabilirsiniz:<br>
# http://www.cs.toronto.edu/~rsalakhu/papers/srivastava14a.pdf

# %% [markdown]
# # Bir ConvNet Örneği - VGGNet

# %% [markdown]
# Large Scale Visual Recognition Challenge 2014 (ILSVRC2014) yarışmasında birinci olan modeli biraz inceleyelim
# <br>Orjinal makale:
# [VERY DEEP CONVOLUTIONAL NETWORKS FOR LARGE-SCALE IMAGE RECOGNITION](https://arxiv.org/pdf/1409.1556.pdf)

# %% [markdown]
# ![imagenet_vgg16.png](imagenet_vgg16.png)

# %% [markdown]
# Şimdi VGG'yi yükleyelim ve katmanlarına bakalım.

# %%
import keras
vgg = keras.applications.vgg16.VGG16()
print(vgg.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# Şimdi genel bir özet aldık katmanları özel olarak inceleyelim. Yukarıdaki makaleden anladığımız kadarıyla:
# * VGG'de her bir convolution adımı 3x3 matrislerden oluşmakta.
# * Girdi imgelerine 1 piksel "pad" yapılmış. Böylece 3x3 bir matris ile "convolve" edildiği zaman yine aynı boyutta bir çıktı elde ediyoruz.
# * "Stride" parametresi ise 1 olarak belirlenmiştir.
# * Max Pooling katmanlar ise 2x2 ve "stride" değeri ise 2

# %%
# Keras'ta bir modelin katmanlarını analiz etmek için layers metodu kullanılır
# Bu metod indekslenebilir. 
# Örneğin ilk katmanın konfigürasyonunu bulalım
vgg.layers[0].get_config()
# Out:
# {'batch_input_shape': (None, 224, 224, 3),
#  'dtype': 'float32',
#  'sparse': False,
#  'name': 'input_2'}

# %%
# Şimdi ikinci katmanı yanı ilk convolution katmanının 
# konfigürasyonuna bakalım 
vgg.layers[1].get_config()
# Out:
# {'name': 'block1_conv1',
#  'trainable': True,
#  'filters': 64,
#  'kernel_size': (3, 3),
#  'strides': (1, 1),
#  'padding': 'same',
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'activation': 'relu',
#  'use_bias': True,
#  'kernel_initializer': {'class_name': 'VarianceScaling',
#   'config': {'scale': 1.0,
#    'mode': 'fan_avg',
#    'distribution': 'uniform',
#    'seed': None}},
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'kernel_regularizer': None,
#  'bias_regularizer': None,
#  'activity_regularizer': None,
#  'kernel_constraint': None,
#  'bias_constraint': None}

# %% [markdown]
# Gördüğünüz gibi ilk "convolutional layer"daki parametreleri kolaylıkla elde ettik.
# Yukarıda konuştuğumuz temel "convolution" kavramlarını hatırlayalım ve buradaki karşılıklarına bakalım:
# * ``'padding': 'same'``: Bu parametre "padding" yapıldığını gösteriyor. "same" girdi ile çıktının aynı şekilde olması için yeterli miktarda sıfır eklendiğini gösteriyor.
# * ``'kernel_size': (3, 3)``: Filtre boyutunun 3x3 olduğunu gösteriyor.
# * ``'strides': (1, 1)``: İlk sayı sütun eksenindeki kaydırma miktarını, ikinci sayı satır eksenindeki kaydırma miktarını belirtiyor. Bunların bir olduğunu görüyoruz.
# * ``'filters': 64``: Tam 64 adet filtre olduğunu anlıyoruz.

# %% [markdown]
# ## İlk katmandaki filtrelerin görselleştirilmesi

# %% [markdown]
# >Bu ilk katmandaki filtreleri görselleştirebilir miyiz acaba? Bunun için ilk katmandaki "weigth"leri yani filrelerin katsayılarını almamız lazım.

# %%
weights = vgg.layers[1].get_weights()
print(weights[0].shape)
# Out:
# (3, 3, 3, 64)

# %%
# 64 adet filtre olduğunu görüyoruz. Bunların her birinin boyutu 3x3x3. Sonundaki 3 katsayısı R,G,B kanalllarını belirtiyor.
# İlk önce değerler nasıl dağılmış bir bakalım
plt.figure()
# Tüm ağırlıkları alıp çizdirelim
plt.hist(np.ndarray.flatten(weights[0]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Buradaki rakamları 0-255 arasında göndermeliyiz ki imge halinde görebilelim. *François Chollet Bey*'in önerdiği fonksiyonu kullanalım.

# %%
# https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
processed = deprocess_image(weights[0][:,:,:,0])
plt.figure()
plt.imshow(processed)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Şimdi hepsini gösterelim isterseniz
plt.figure()
for i in range(64):
    ax = plt.subplot(8,8,i+1)
    processed = deprocess_image(weights[0][:,:,:,i])
    plt.imshow(processed)
    ax.set_xticks([])
    ax.set_yticks([])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Buraya kadar okuduğunuz için çok teşekkürler. Bir başka yazıda görüşmek üzere, esen kalın!
