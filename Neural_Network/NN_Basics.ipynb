# %% [markdown]
# <div align="right">
# <table style="width:50%">
#   <tr>
#     <th>Hazırlayan</th>
#     <th>Versiyon</th>
#     <th>Tarih</th>
#     <th>Dil</th>
#   </tr>
#   <tr>
#     <td>dataFLOYD</td>
#     <td>v1.00</td>
#     <td>13 Eyl 2018</td>
#     <td>TR </td>
#   </tr>
# </table>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <br>
# Başlamadan önce henüz bakmadıysanız aşağıdaki yazıları gözden geçirmenizi öneririm <br>
# <br>
# ÖN KOŞULLAR
#     <br><a href="https://www.datafloyd.com/tr/veri-bilimi-icin-temel-python-kullanimi/">Temel Python kullanımı</a>
#     <br><a href="https://www.datafloyd.com/tr/pyhton-numpy-kutuphanesinin-kullanimi/">Numpy kütüphanesi kullanımı</a>
#         <br><a href="https://www.datafloyd.com/tr/pyhton-matplotlib-kutuphanesini-kullanarak-veri-gorsellestirme-temel-grafikler%C2%B6/">Python “matplotlib” kütüphanesini kullanarak temel görselleştirme</a>
# <br><a href="https://www.datafloyd.com/tr/confusion-matrix-hakkinda/">"Confusion matrix" hakkında</a>
# </div>

# %% [markdown]
# # YAPAY SİNİR AĞLARI (NEURAL NETWORKS) 1. BÖLÜM
# TEK BİR NÖRON HAKKINDA

# %% [markdown]
# <div class="well">
# Birbirimizi kandırmayalım internette "zibilyon" tane yapay sinir ağları yazısı mevcut, bunu siz de biliyorsunuz. Birçoğuna bakmışsınızdır zaten. Bunların en önemli ortak noktası hepsinin de yakışıklı (!) bir nöron resmi ile başlaması ve NN ile analoji kurmaya çalışmasıdır. <br><br>Nöron ile başlamak kötüdür demek istemiyorum, sonuçta meşhur <a href="https://www.youtube.com/watch?v=Ze9-wg9k7AU">"Fight Club"</a> filmi bile nöronlarla başlıyor! (<b>David Fincher</b> abimiz bile bu yolu seçtiyse vardır bir bildiği...) Bu sebeple başlığa bu meşhur filmin bir posterini koydum :) İzlemeyenler mutlaka izlesin bu filmi, her ne kadar şiddete karşı olsam da "şiddetle" tavsiye ediyorum bu  filmi. Neyse konumuza dönelim şimdi.
# </div>

# %% [markdown]
# ------------

# %% [markdown]
# <div class="alert alert-info">
# <b>Soru :</b> Nereden başlasak bilemedim ki? Siz yönlendirin bari.. <br>
# </div>
#
# <div class="alert alert-success">
# <b>Cevap :</b> Bence başlamadan önce "ihtiyacımız olacak kadar" matrislere bakalım. Çünkü az sonra bunların grafiksel gösterimleri önem kazanacak. <br>
# $W$, ve $x$ adında iki tane sütun matrisimiz ve bir adet $b$ adında sabit terimimiz olsun.
# </div>

# %% [markdown]
# \begin{equation*}
# W=
# \begin{bmatrix}
# w_0 \\
# \vdots \\
# w_n
# \end{bmatrix}
# \quad
# x=
# \begin{bmatrix}
# x_0 \\
# \vdots \\
# x_n
# \end{bmatrix}
# \quad
# b
# \end{equation*}

# %% [markdown]
# Şimdi $y=W^Tx+b$ yazdığımızda ne olur?

# %% [markdown]
# \begin{equation*}y=w_0x_0+...+w_nx_n + b\end{equation*}

# %% [markdown]
# $W$ değişkenine ağırlıklar (weights) $x$ değişkenine girdiler/öznitelikler (input/features) dersek. Yukarıda ifade ettiğimiz denklem girdiler ile çıktıların çarpılıp, sonrasında sabit bir terim ile toplanması olarak ifade edilmektedir.

# %% [markdown]
# Şimdi bu matris çarpımı olarak yazıdğımız denklem aslında toplam olarak da ifade edilebilir. Onu da yazalım:

# %% [markdown]
# \begin{equation*}y=W^Tx+b=\sum_{i=0}^n{w_ix_i}+b\end{equation*}

# %% [markdown]
# ------------

# %% [markdown]
# <div class="alert alert-info">
# <b>Soru :</b> dataFLOYD bey iyi ki yönlendirmeyi size bıraktık... Denkleme boğdunuz bizi, ne demek bu denklemler, neler oluyor? <br>
# </div>
#
# <div class="alert alert-success">
# <b>Cevap :</b>  Yani tabi ama, ne bileyim, neyse... Bu denklemleri bir de grafik olarak göstereyim belki işe yarar.
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Bu şekil her kaynakta farklı farklı gösterilir fakat temelde yapılan şey aynıdır. Girdileri ağırlıklarla çarp ve topla,sonrasında ise sabit bir terim ekle.

# %% [markdown]
# Şekilde birşey daha dikkatinizi çekti mi? Şeklin en sonunda bir fonksiyon mevcut. Bu fonksiyona **aktivasyon fonksiyonu** denilmektedir. **Aktivasyon fonksiyonu** ortaya çıkan y değerinin non-lineer şekilde davranmasını sağlamaktadır.

# %% [markdown]
# <div class="alert alert-warning">
# Yukarıdaki şekildeki yapı genellikler <b> tek bir nöron </b>olarak tanımlanmaktadır.
# </div>

# %% [markdown]
# Tek bir nöron denklemini aktivasyon fonksiyonunu da kullanarak tanılayalım

# %% [markdown]
# \begin{equation*}y'=f(W^Tx+b)=f(\sum_{i=0}^n{w_ix_i}+b)\end{equation*}

# %% [markdown]
# ------------

# %% [markdown]
# <div class="alert alert-info">
# <b>Soru :</b> Aktivasyon fonksiyonu sürpriz oldu doğrusu. Bu fonksiyon nasıl bir şeydir? Türleri var mıdır? <br>
# </div>
#
# <div class="alert alert-success">
# <b>Cevap :</b>  Aktivasyon fonksiyonunun non-lineer davranışı sınıflandırıcının kompleks ilişkileri öğrenebilmesini sağlar. Ne güzel laf değil mi:) İsterseniz en çok bilinen aktivasyon fonksiyonlarını gözden geçirelim.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# Bu kısma geçmeden önce <b>"vanishing gradient"</b> probleminden biraz haberimiz olması gerekiyor. <br><br>
# Henüz mimarilere geçmedik ama şunu bilseniz yeterli bu kötü birşeydir :). Yapay sinir ağının eğitimini çok uzatır ve "accuracy" değerini düşürür. <br><br>
# Niye böyle oluyor, çünkü  "backpropagation" yaparken hata değerleri geriye doğru gittikçe küçülüyor. Çok küçülmesi baştaki katmanların iyi bir şekilde öğrenmesini engelliyor. Haliyle ilk katmanlar düzgün öğrenemediği sonraki gelen katmalar da düzgün çalışamıyor. <br><br>
# Konuyu ayrıntılı olarak incelemek isterseniz aşağıdaki makaleleri tavsiye ederim.<br>
# <a href="http://neuralnetworksanddeeplearning.com/chap5.html">Why are deep neural networks hard to train?</a>
# <br>
# <a href="https://ayearofai.com/rohan-4-the-vanishing-gradient-problem-ec68f76ffb9b">The vanishing gradient problem</a>
#
# </div>

# %% [markdown]
# ### ADIM FONKSİYONU (STEP FUNCTION)

# %% [markdown]
# Bu fonksiyon 1 veya 0 çıktısı verir. Genellikle ikiili sınıflandırma problemlerinde "perceptron" sınıflandırıcısı ile birlikte kullanılır.

# %% [markdown]
# *Not: "Perceptron" girdileri lineer olarak birleştirerek tahmin yapmaya çalışan bir ikili sınıflandırma algoritmasıdır.*

# %%
import numpy as np
import matplotlib.pyplot as plt
# Seaborn dark theme tercihimizdir :)
import seaborn as sns
sns.set_style("darkgrid")

# %matplotlib notebook

# %%
plt.figure()
plt.step([-4,0,4],[0,0,1],linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("Adım Fonksiyonu");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### TANH

# %% [markdown]
# Çok büyük sayıları 1'e çok küçük sayıları -1'e sıkıştırır. ***"Vanishing Gradient" problemi mevcut***

# %%
plt.figure()
x = np.linspace(-4,4,100) # -1 ile 1 arasında x oluşturalım
plt.plot(x,np.tanh(x),linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("tanh");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### ATAN

# %% [markdown]
# Girdileri $-\pi/2$ ile $\pi/2$ arasına sıkıştırır. *tanh* ile 0 civarında benzer bir karakteristik sergiler fakat tanh'ye göre daha yumuşaktır. ***"Vanishing Gradient" problemi mevcut***

# %%
plt.figure()
x = np.linspace(-10,10,100) # -1 ile 1 arasında x oluşturalım
plt.plot(x,np.arctan(x),linewidth=3)
plt.plot(x,np.tanh(x),linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("atan")
plt.legend(["atan","tanh"]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### HARD TANH

# %% [markdown]
# *tanh* fonksiyonuna göre işlem yükü daha azdır.

# %%
plt.figure()
x = np.linspace(-4,4,100) # -1 ile 1 arasında x oluşturalım
plt.plot(x,np.maximum(-1, np.minimum(1, x)),linewidth=3)
plt.plot(x,np.tanh(x),linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("Hard tanh");
plt.legend(["Hard tanh","tanh"]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### SIGMOID

# %% [markdown]
# Girdileri 0 ile 1 arasına sıkıştırır. ***"Vanishing Gradient" problemi mevcut***

# %%
plt.figure()
x = np.linspace(-10,10,100) # -1 ile 1 arasında x oluşturalım
plt.plot(x,1 / (1 + np.exp(-x)),linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("Sigmoid");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### RELU (RECTIFIED LINEAR UNIT)

# %% [markdown]
# Çok kral bir fonksiyondur :) "Vanishing gradient" problemi yoktur. Bu sebeple derin öğrenmede daha hızlı ve kesin sonuç alabilmemizi sağlar.

# %%
plt.figure()
x = np.linspace(-10,10,100) # -1 ile 1 arasında x oluşturalım
plt.plot(x,np.maximum(0, x),linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("RELU");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### LEAKY RELU

# %% [markdown]
# RELU verken niye buna ihtiyaç çıktı denilebilir. Ne yazık ki bazen RELU'lar ölebiliyor (dying relu problem) ve girdilere hiç tepki vermiyor. Eğitim aşamasında bunun önüne geçebilmek için RELU'nun 0 olan kısmına hafif eğim verilir.

# %%
plt.figure()
x = np.linspace(-10,1,100) # -1 ile 1 arasında x oluşturalım
plt.plot(x,np.maximum(0.02 * x, x),linewidth=3)
plt.xlabel("input")
plt.ylabel("output")
plt.title("Leaky RELU");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Şimdilik bu kadar yetsin, yoruldum :) Bu serinin devamı gelecek, bir sonraki bölümde **mimarileri ve "backpropagation"** olayını anlatacağım. Tekrar görüşünceye kadar hoşçakalın!
